# %%
mc_file = "/home/benr/wqmodels/ssm/wqm_inputs/SSM_2013_T189a1_ZP_SAV_HYD_200m_0.7alb_T41z0_0.24_PM300_zpT76_WS7.5/meteorologic_fullgrid.dat"
out_file = "/home/benr/Documents/Education/UW/CEE800/SSM Freshwater/phase 2/inputs_parsed/ssm_met_2013.xlsx"

import pandas as pd

# %%
df = pd.read_table(mc_file, skiprows=3, index_col=0, sep='\s+')
df
# Out:
#           KT     TE      IO     FD     WS
# JDAY
# 0.0    14.94  23.03  11.794  0.280  2.215
# 0.5    14.94  23.03  11.794  0.280  2.215
# 1.5    14.94  23.03  11.938  0.280  4.823
# 2.5    14.94  23.03  11.542  0.280  4.744
# 3.5    14.94  23.03   9.507  0.280  5.410
# ...      ...    ...     ...    ...    ...
# 361.5  14.94  23.03  11.020  0.327  2.327
# 362.5  14.94  23.03   2.799  0.327  2.465
# 363.5  14.94  23.03   5.055  0.327  2.807
# 364.5  14.94  23.03   7.247  0.327  4.820
# 365.0  14.94  23.03   7.247  0.327  4.820
#
# [367 rows x 5 columns]

# %%
df.to_excel(out_file)
